# %%
from lxml import html
from lxml import objectify
import requests
import json
import pandas as pd
import csv
import numpy as np
import time
import os
os.getcwd()
from Utils import utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-62-53d513ff549c> in <module>()
#       9 import os
#      10 os.getcwd()
# ---> 11 from Utils import utils
#
# ModuleNotFoundError: No module named 'Utils'

# %%
class Scraper_REI:
    def __init__(self):
        BASE_URL = 'https://www.rei.com'
        HEADERS = {
            'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36",
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.9',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
            'referer': 'https://www.google.com/',
        }
    
    def getSpecs_REI(self, url):
        tree = self.get(url)

    #     # get product name
    #     metadata = tree.xpath('//script[@data-client-store="product-metadata"]')[0]
    #     metadata = html.tostring(metadata).decode()
    #     metadata = metadata.split('<script type="application/json" data-client-store="product-metadata">')[1].split('</script>')[0]
    #     metadata = metadata.replace('\n', '')
    #     metadata = json.loads(metadata)

        # get product specs
        specs = tree.xpath('//script[@data-client-store="product-details"]')[0]
        specs = html.tostring(specs).decode()
        specs = specs.split('<script type="application/json" data-client-store="product-details">')[1].split('</script>')[0]
        specs = specs.replace('\n', '')
        specs = json.loads(specs)

        # get product price
        summary = tree.xpath('//script[@type="application/ld+json"]')[0]
        summary = html.tostring(summary).decode()
        summary = summary.split('<script type="application/ld+json">')[1].split('</script>')[0]
        summary = summary.replace('\n', '')
        summary = json.loads(summary)

        data = {}
        data['URL'] = url
        data['Name'] = summary["name"]
        data['Brand'] = specs["brand"]
        data['lowPrice'] = summary['offers'][0]['price']
        data['highPrice'] = summary['offers'][-1]['price']
        data['PriceCurrency'] = summary['offers'][0]['priceCurrency']
        if "overall" in specs["reviewsSummary"]:
            data['Rating'] = specs["reviewsSummary"]["overall"]
            data['NumRatings'] = specs["reviewsSummary"]["total"]
        for item in specs["specs"]:
            data[item["name"]] = item["values"][0]
        return data
    
    
    def getSpecs_REI_Garage(self, url):
        tree = self.get(url)

        info = tree.xpath('//script[@id="page-data"]/text()')[0]
        info = info.replace('\n', '')
        info = json.loads(info)
        info = info["product"]
        specs = info['specifications']

        data = {}
        data["URL"] = url
        data["Name"] = info["title"] # maybe use info["cleanTitle"]
        data["Image"] = "https://www.rei.com" + info["media"][0]['product']
        data["Brand"] = info["brand"]["label"] # maybe replace "label" with "canonicalName"
        data["lowPrice"] = info["displayPrice"]["min"]
        data["highPrice"] = info["displayPrice"]["max"]
        data["PriceCurrency"] = "USD" # TODO change "USD" to actually find and grab currency
        if "overall" in info["reviewsSummary"]:
            data['Rating'] = info["reviewsSummary"]["overall"]
            data['NumRatings'] = info["reviewsSummary"]["total"]
        else:
            data['Rating'] = -1
            data['NumRatings'] = 0
        for item in specs["specs"]:
            data[item["name"]] = item["values"][0]
        return data
    
    def getProductsFromPage_REI(self, url):
        tree = self.get(url)

        prodList = tree.xpath('//div[@id="search-results"]/.//a')

        links = []
        for index, item in enumerate(prodList):
            if index % 2 != 0:
                continue
            link = html.tostring(item).decode()
            link = link.split('href="')[1].split('"')[0]
            if 'product' in link:
                links.append(link)
        return links
    
    
    def getPages_REI(self, url):
        tree = self.get(url)

        pages = tree.xpath('//nav[@class="_3-4shQxwfGRyzNItrZFEiC"]/.//a/text()')
        if(len(pages) == 0):
            return [url]
        numPages = int(pages[-1])
        urlList = []
        if "?" in url:
            pagesStr = "&page="
        else:
            pagesStr = "?page="
        for i in range(numPages):
            pageUrl = url + pagesStr + str(i+1)
            urlList.append(pageUrl)
        return urlList
    
    
    def getProducts_REI(self, urls):
        baseURL = "https://www.rei.com"
        urlPages = getPages_REI(urls) # get urls of each page of the website category
        urlProducts = []
        for url in urlPages: #get urls of each product on each page and append to list
            productsURL = getProductsFromPage_REI(url)
            for productURL in productsURL:
                urlProducts.append(productURL)
        products = []
        for prodURL in urlProducts:
            print(prodURL)
            # different scraping methods needed for rei garage
            if "rei-garage" not in prodURL: 
                specs = getSpecs_REI(baseURL + prodURL)
            else:
                specs = getSpecs_REI_Garage(baseURL + prodURL)
            products.append(specs) # append product list to specs
        return products
    
    
    def scrape_REI(self, categories):
        products = {}
        for category in categories:
            print(category)
            products[category] = []
            for url in categories[category]:
                products[category].append(getProducts_REI(url))
        return products
    
    
    # helper function for get requests
    def get(self, url):
        # sleep to add variable pauses in requests
        delay = np.random.randint(20)
        time.sleep(delay)

        #request then convert data into html element
        page = requests.get(url, headers=self.HEADERS)
        tree = html.fromstring(page.content)
        return tree

# %%
def save_json(dict):
    jsons = json.dumps(dict)
    f = open("data.json","w")
    f.write(jsons)
    f.close()

def save_csv(data):
    csv_file = "data.csv"
    try:
        print(data)
        with open(csv_file, 'w') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=data.keys())
            writer.writeheader()
            for d in data:
                writer.writerow(d)
    except IOError:
        print("I/O error")

# %%
categories = {}

backPackURLs = [
    'https://www.rei.com/c/backpacking-packs',
    'https://www.rei.com/c/day-packs',
    'https://www.rei.com/c/hiking-hydration-packs',
    'https://www.rei.com/c/baby-carrier-packs'
]

tentURLS = [
    'https://www.rei.com/c/backpacking-tents',
    'https://www.rei.com/c/camping-tents',
    
]

bivyURLs = [
    'https://www.rei.com/c/bivy-sacks'
]

sleepingBagURLs = [
    'https://www.rei.com/c/mens-sleeping-bags',
    'https://www.rei.com/c/womens-sleeping-bags',
    'https://www.rei.com/c/double-sleeping-bags',
    'https://www.rei.com/c/kids-sleeping-bags',   
]

categories['Backpack'] = backPackURLs
categories['Tent'] = tentURLS
categories['Bivy'] = bivyURLs
categories['Sleeping Bag'] = sleepingBagURLs

# %%
data = scrape_REI(categories)
# Out:
# /product/134072/osprey-atmos-ag-65-pack-mens
# /product/168251/rei-co-op-trailbreak-60-pack-mens
# /product/141492/osprey-kyte-46-pack-womens
# /product/144662/osprey-rook-65-pack-mens
# /product/126937/rei-co-op-traverse-35-pack-mens
# /rei-garage/product/162516/gregory-paragon-58-pack-mens
# /product/125754/gregory-baltoro-65-pack-mens
# /product/126717/osprey-aura-ag-65-pack-womens
# /product/148589/rei-co-op-flash-55-pack-mens
# /product/141491/osprey-kestrel-48-pack-mens
# /rei-garage/product/162514/gregory-maven-55-pack-womens
# /product/127753/deuter-aircontact-lite-65-10-pack-mens
# /rei-garage/product/162515/gregory-paragon-48-pack-mens
# /product/126716/osprey-aura-ag-50-pack-womens
# /product/144663/osprey-renn-65-pack-womens
# /rei-garage/product/168378/alps-mountaineering-baja-60-pack
# /product/126707/osprey-atmos-ag-50-pack-mens
# /product/168252/rei-co-op-trailbreak-60-pack-womens
# /product/111288/osprey-tempest-40-pack-womens
# /product/111240/osprey-talon-44-pack-mens
# /product/126709/osprey-exos-58-pack-mens
# /product/126938/rei-co-op-traverse-35-pack-womens
# /product/154462/osprey-renn-50-pack-womens
# /rei-garage/product/151563/alps-mountaineering-wasatch-55-pack
# /product/154460/osprey-rook-50-pack-mens
# /product/125757/gregory-deva-60-pack-womens
# /product/111291/osprey-ariel-ag-65-pack-womens
# /product/168253/rei-co-op-tarn-40-pack-kids
# /product/123205/gregory-baltoro-75-pack-mens
# /product/125529/deuter-aircontact-lite-45-10-sl-pack-womens
# /product/126711/osprey-xenith-75-pack-mens
# /product/126712/osprey-xenith-105-pack-mens
# /product/151848/hyperlite-mountain-gear-2400-windrider-pack
# /product/177493/osprey-aether-65-pack-mens
# /product/177497/osprey-aether-plus-85-pack-mens
# /product/146742/granite-gear-blaze-60-pack-womens
# /product/111293/osprey-ariel-ag-75-pack-womens
# /product/148671/rei-co-op-flash-55-pack-womens
# /product/127756/deuter-aircontact-lite-60-10-sl-pack-womens
# /product/112645/granite-gear-crown2-60-pack-mens
# /product/159408/gregory-paragon-58-pack-mens
# /product/148588/rei-co-op-flash-45-pack-mens
# /product/127758/deuter-fox-40-pack-kids
# /product/133307/osprey-mutant-38-pack
# /product/140812/gregory-octal-45-pack-womens
# /product/126934/rei-co-op-traverse-70-pack-mens
# /product/145651/gregory-jade-38-pack-womens
# /product/177499/osprey-ariel-65-pack-womens
# /product/142360/osprey-lumina-60-pack-womens
# /product/872874/gregory-denali-100-pack
# /product/166788/mountain-hardwear-amg-55-pack
# /product/151861/hyperlite-mountain-gear-4400-southwest-pack
# /product/126713/osprey-xenith-88-pack-mens
# /product/165338/gregory-maven-45-pack-womens
# /product/159409/gregory-maven-55-pack-womens
# /product/164356/osprey-archeon-65-pack-womens
# /product/126718/osprey-eja-48-pack-womens
# /product/126705/osprey-exos-48-pack-mens
# /product/125528/deuter-aircontact-lite-50-10-pack-mens
# /product/144965/mystery-ranch-glacier-pack-mens
# /product/126720/osprey-xena-70-pack-womens
# /product/125758/gregory-deva-80-pack-womens
# /product/130011/deuter-futura-pro-36-pack-mens
# /product/123206/gregory-deva-70-pack-womens
# /product/127239/granite-gear-crown2-38-pack
# /product/164355/osprey-archeon-45-pack-womens
# /product/177498/osprey-ariel-55-pack-womens
# /product/165341/gregory-maven-65-pack-womens
# /product/125755/gregory-baltoro-85-pack-mens
# /product/127755/deuter-futura-vario-45-10-sl-pack-womens
# /product/145653/gregory-jade-63-pack-womens
# /product/145640/gregory-zulu-65-pack-mens
# /product/117533/gregory-alpinisto-50-pack
# /product/145639/gregory-zulu-55-pack-mens
# /product/165340/gregory-amber-55-pack-womens
# /product/140811/gregory-optic-48-pack
# /product/145638/gregory-zulu-40-pack-mens
# /product/127754/deuter-futura-pro-34-sl-pack-womens
# /product/148577/rei-co-op-trail-hydro-30l-hydration-pack-mens-3-liters
# /product/126376/gregory-swift-25-hydration-pack-womens-3-liters
# /product/113327/osprey-stratos-34-pack-mens
# /product/177574/osprey-tempest-20-pack-womens
# /product/145025/patagonia-nine-trails-pack-20l-mens
# /product/145115/yeti-panga-pack-28
# /product/165344/gregory-citro-24-h2o-hydration-pack-mens-3-liters
# /product/144667/osprey-skarab-30-hydration-pack-mens-25-liters
# /product/171493/salomon-xa-25-hydration-pack
# /product/145658/gregory-zulu-30-pack-mens
# /product/144968/mystery-ranch-scree-32-pack-mens
# /product/165343/gregory-nano-h2o-22l-hydration-pack-3-liters
# /product/126722/osprey-hikelite-26-pack
# /product/164360/osprey-archeon-25-pack-mens
# /product/143535/deuter-trail-30-pack-mens
# /product/170769/camelbak-arete-18-hydration-pack-15-liters
# /product/145657/gregory-miwok-24-pack-mens
# /product/142981/gregory-swift-20-hydration-pack-3-liters-womens
# /product/147413/deuter-trail-pro-32-pack-mens
# /product/165347/gregory-juno-30-h2o-hydration-pack-womens-3-liters
# /product/124962/patagonia-nine-trails-26l-pack-womens
# /product/170722/kelty-redwing-50-pack-mens
# /product/157497/fjallraven-ulvo-23-pack
# /product/176933/rei-co-op-1982-summit-pack
# /product/164402/osprey-archeon-25-pack-womens
# /product/142949/gregory-inertia-20-hydration-pack-3-liters
# /product/144969/mystery-ranch-coulee-25-pack-womens
# /product/147406/deuter-trail-pro-36-pack-mens
# /product/147416/deuter-trail-pro-30-sl-pack-womens
# /product/148929/ultraspire-bryce-xt-hydration-pack
# /product/149213/ultimate-direction-fastpackher-20-pack-womens
# /product/175966/camelbak-octane-25l-hydration-pack-2-liters
# /product/167628/deuter-speed-lite-32-pack-mens
# /product/170724/kelty-redwing-50-pack-womens
# /product/175965/camelbak-octane-18l-hydration-pack-2-liters
# /product/166796/mountain-hardwear-camp-4-28-pack
# /product/169964/thule-alltrail-x-25l-pack
# /product/126377/gregory-swift-30-hydration-pack-womens-3-liters
# /product/170723/kelty-redwing-36-pack-womens
# /product/170721/kelty-redwing-36-pack-mens
# /product/102017/rei-co-op-tarn-18-pack-kids
# /product/179852/cotopaxi-fiesta-day-pack-duffel-bundle
# /product/176208/cgear-multimats-sand-free-switch-transitional-pack
# /product/149213/ultimate-direction-fastpackher-20-pack-womens
# /product/175966/camelbak-octane-25l-hydration-pack-2-liters
# /product/167628/deuter-speed-lite-32-pack-mens
# /product/170724/kelty-redwing-50-pack-womens
# /product/175965/camelbak-octane-18l-hydration-pack-2-liters
# /product/166796/mountain-hardwear-camp-4-28-pack
# /product/169964/thule-alltrail-x-25l-pack
# /product/126377/gregory-swift-30-hydration-pack-womens-3-liters
# /product/170723/kelty-redwing-36-pack-womens
# /product/170721/kelty-redwing-36-pack-mens
# /product/169963/thule-alltrail-x-15l-pack
# /product/102017/rei-co-op-tarn-18-pack-kids
# /product/179852/cotopaxi-fiesta-day-pack-duffel-bundle
# /product/176208/cgear-multimats-sand-free-switch-transitional-pack
# /product/170805/camelbak-sequoia-24-hydration-pack-womens-3-liters
# /product/107475/marmot-trestles-15-sleeping-bag-womens
# /product/128369/the-north-face-cats-meow-20-sleeping-bag-womens
# /product/152799/sea-to-summit-flame-fmiv-15-sleeping-bag-womens
# /product/111166/rei-co-op-joule-21-sleeping-bag-womens
# /product/127863/marmot-angel-fire-25-sleeping-bag-womens
# /product/152791/sea-to-summit-quest-quii-30-sleeping-bag-womens
# /product/107476/marmot-trestles-30-sleeping-bag-womens
# /product/163036/nemo-riff-30-sleeping-bag-womens
# /product/147316/big-agnes-daisy-mae-15-sleeping-bag-womens
# /product/152796/sea-to-summit-flame-fmiii-25-sleeping-bag-womens
# /product/152798/sea-to-summit-altitude-atii-15-sleeping-bag-womens
# /product/147317/big-agnes-daisy-mae-0-sleeping-bag-womens
# /product/127864/marmot-teton-15-sleeping-bag-womens
# /product/168180/big-agnes-torchlight-30-sleeping-bag-womens
# /product/153204/mountain-equipment-glacier-1000-sleeping-bag-womens
# /product/153201/mountain-equipment-glacier-700-sleeping-bag-womens
# /product/152797/sea-to-summit-journey-joii-18-sleeping-bag-womens
# /product/111166/rei-co-op-joule-21-sleeping-bag-womens
# /product/107476/marmot-trestles-30-sleeping-bag-womens
# /product/175961/mountain-equipment-helium-400-sleeping-bag-womens
# /product/175962/mountain-equipment-helium-800-sleeping-bag-womens
# /rei-garage/product/184708/nemo-aya-30-sleeping-bag-womens
# /rei-garage/product/183085/mountain-equipment-sleepwalker-iii-sleeping-bag-womens
# /rei-garage/product/184706/nemo-aya-15-down-mummy-sleeping-bag-womens-long
# /rei-garage/product/184707/nemo-aya-15-down-mummy-sleeping-bag-womens
# /rei-garage/product/184709/nemo-aya-30-sleeping-bag-womens-long
# /rei-garage/product/183577/big-agnes-sarvis-sl-30-sleeping-bag-womens
# /rei-garage/product/183576/big-agnes-sarvis-sl-30-sleeping-bag-womens-petite
# /rei-garage/product/183087/mountain-equipment-sleepwalker-ii-sleeping-bag-womens
# /product/138138/exped-megasleep-duo-2540-double-sleeping-bag
# /product/127390/rei-co-op-kindercone-25-sleeping-bag-kids
# /rei-garage/product/184274/eureka-lady-bug-sleeping-bag-kids
# /product/127389/rei-co-op-kindercamp-40-sleeping-bag-kids
# /product/178516/morrison-outdoors-big-mo-40-kids-sleeping-bag-toddlers
# /product/178515/morrison-outdoors-big-mo-20-kids-sleeping-bag-toddlers
# /product/174488/the-north-face-youth-eco-trail-synthetic-20-sleeping-bag-kids
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-65-fb99845e8afd> in <module>()
#       1 data = scrape_REI(categories)
# ----> 2 save(data)
#
# <ipython-input-63-dda934e78a87> in save(dict)
#       1 def save(dict):
# ----> 2     json = json.dumps(dict)
#       3     f = open("data.json","w")
#       4     f.write(json)
#       5     f.close()
#
# UnboundLocalError: local variable 'json' referenced before assignment

# %%
save_csv(data)
# Out:
# {'Backpack': {'Poco Child Carrier': {'URL': 'https://www.rei.com/product/164404/osprey-poco-child-carrier', 'Name': 'Poco Child Carrier', 'Brand': 'Osprey', 'lowPrice': '290', 'highPrice': '290', 'PriceCurrency': 'USD', 'Best Use': 'Hiking', 'Bag Style': 'Backpack', 'Frame Type': 'External Frame', 'Gear Capacity (L)': '20 liters', 'Gear Capacity (cu. in.)': '1,220 cubic inches', 'Weight': '7 lbs. 11.2 oz.', 'Max. Weight (Child+Gear+Pack)': '48 lbs. 8 oz.', 'Adjustable Torso Length': 'Yes', 'Fits Torso Length (in.)': '15-21 inches', 'Fits Waist/Hips': '26-48 inches', 'Material(s)': '210-denier nylon diamond', 'Frame Material': 'Aluminum', 'Suspended Mesh Back Panel': 'Yes', 'Pack Access': 'Top / Panel', 'Number of Exterior Pockets': '6 + main compartment', 'Hipbelt': 'Yes', 'Hipbelt Pockets': 'Yes', 'Dimensions': '28 x 17.75 x 15.75 inches', 'Gender': 'Unisex'}, 'Kid Comfort Pro Child Carrier': {'URL': 'https://www.rei.com/product/147420/deuter-kid-comfort-pro-child-carrier', 'Name': 'Kid Comfort Pro Child Carrier', 'Brand': 'Deuter', 'lowPrice': '330', 'highPrice': '330', 'PriceCurrency': 'USD', 'Rating': 4.9231, 'NumRatings': 13, 'Best Use': 'Hiking', 'Bag Style': 'Backpack', 'Frame Type': 'External Frame', 'Gear Capacity (L)': '14 liters', 'Gear Capacity (cu. in.)': '854 cubic inches', 'Weight': '8 lbs. 5 oz.', 'Max. Weight (Child+Gear+Pack)': '48 lbs. 8 oz.', 'Adjustable Torso Length': 'Yes', 'Fits Torso Length (in.)': '15-20 inches', 'Fits Waist/Hips': '24-54 inches', 'Material(s)': '210-denier polyamide polyester', 'Frame Material': 'Aluminum', 'Suspended Mesh Back Panel': 'Yes', 'Number of Exterior Pockets': 'Unavailable', 'Hipbelt': 'Yes', 'Hipbelt Pockets': 'Yes', 'Dimensions': '31 x 17 x 13 inches', 'Gender': 'Unisex'}, 'Poco Plus Child Carrier': {'URL': 'https://www.rei.com/product/164405/osprey-poco-plus-child-carrier', 'Name': 'Poco Plus Child Carrier', 'Brand': 'Osprey', 'lowPrice': '330', 'highPrice': '330', 'PriceCurrency': 'USD', 'Rating': 4.6667, 'NumRatings': 15, 'Best Use': 'Hiking', 'Bag Style': 'Backpack', 'Frame Type': 'External Frame', 'Gear Capacity (L)': '26 liters', 'Gear Capacity (cu. in.)': '1,587 cubic inches', 'Weight': '7 lbs. 14.4 oz.', 'Max. Weight (Child+Gear+Pack)': '49 lbs. 8 oz.', 'Adjustable Torso Length': 'Yes', 'Fits Torso Length (in.)': '15-22 inches', 'Fits Waist/Hips': '26-49 inches', 'Material(s)': '210-denier nylon diamond', 'Frame Material': 'Aluminum', 'Suspended Mesh Back Panel': 'Yes', 'Pack Access': 'Top / Panel', 'Number of Exterior Pockets': '10 + main compartment', 'Hipbelt': 'Yes', 'Hipbelt Pockets': 'Yes', 'Dimensions': '28.75 x 19 x 15.75 inches', 'Gender': 'Unisex'}, 'Kid Comfort 1 Child Carrier': {'URL': 'https://www.rei.com/product/864892/deuter-kid-comfort-1-child-carrier', 'Name': 'Kid Comfort 1 Child Carrier', 'Brand': 'Deuter', 'lowPrice': '210', 'highPrice': '210', 'PriceCurrency': 'USD', 'Rating': 3.75, 'NumRatings': 4, 'Best Use': 'Hiking', 'Bag Style': 'Backpack', 'Frame Type': 'External Frame', 'Gear Capacity (L)': '14 liters', 'Gear Capacity (cu. in.)': '850 cubic inches', 'Weight': '5 lbs. 7 oz.', 'Max. Weight (Child+Gear+Pack)': '48.5 pounds', 'Adjustable Torso Length': 'Yes', 'Fits Torso Length (in.)': '15 - 21 inches', 'Fits Waist/Hips': '22 - 56 inches', 'Material(s)': 'Polyester/ripstop nylon', 'Frame Material': 'Aluminum', 'Number of Stays': '2', 'Suspended Mesh Back Panel': 'Yes', 'Pack Access': 'Front', 'Number of Exterior Pockets': '3 + main compartment', 'Dimensions': '27 x 15 x 12 inches', 'Gender': 'Unisex'}, 'Kid Comfort Sun Roof': {'URL': 'https://www.rei.com/product/147422/deuter-kid-comfort-sun-roof', 'Name': 'Kid Comfort Sun Roof', 'Brand': 'Deuter', 'lowPrice': '30', 'highPrice': '30', 'PriceCurrency': 'USD', 'Rating': 3.2222, 'NumRatings': 9, 'Best Use': 'Hiking', 'Material(s)': 'Unavailable', 'Dimensions': 'Unavailable', 'Weight': '5 ounces'}, "Kid Comfort Active SL Child Carrier - Women's": {'URL': 'https://www.rei.com/product/147419/deu ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-52843b4f5ab0> in <module>()
# ----> 1 save_csv(data)
#
# <ipython-input-77-a170f138c0da> in save_csv(data)
#      13             writer.writeheader()
#      14             for d in data:
# ---> 15                 writer.writerow(d)
#      16     except IOError:
#      17         print("I/O error")
#
# ~\Anaconda3\lib\csv.py in writerow(self, rowdict)
#     153
#     154     def writerow(self, rowdict):
# --> 155         return self.writer.writerow(self._dict_to_list(rowdict))
#     156
#     157     def writerows(self, rowdicts):
#
# ~\Anaconda3\lib\csv.py in _dict_to_list(self, rowdict)
#     146     def _dict_to_list(self, rowdict):
#     147         if self.extrasaction == "raise":
# --> 148             wrong_fields = rowdict.keys() - self.fieldnames
#     149             if wrong_fields:
#     150                 raise ValueError("dict contains fields not in fieldnames: "
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
scrape_REI(categories)
# Out:
# Backpack
# https://www.rei.com/c/backpacking-packs
#
#
# https://www.rei.com/c/day-packs
#
#
# https://www.rei.com/c/hiking-hydration-packs
#
#
# https://www.rei.com/c/baby-carrier-packs
#
#
# Tent
# https://www.rei.com/c/backpacking-tents
#
#
# https://www.rei.com/c/camping-tents
#
#
# Bivy
# https://www.rei.com/c/bivy-sacks
#
#
# Sleeping Bag
# https://www.rei.com/c/mens-sleeping-bags
#
#
# https://www.rei.com/c/womens-sleeping-bags
#
#
# https://www.rei.com/c/double-sleeping-bags
#
#
# https://www.rei.com/c/kids-sleeping-bags
# {}

# %%
# helper function for get requests
def get(url):
    headers = {
        'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36",
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.9',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'referer': 'https://www.google.com/',
    }
    
    # sleep to add variable pauses in requests
    delay = np.random.randint(20)
    time.sleep(delay)
    
    #request then convert data into html element
    page = requests.get(url, headers=headers)
    tree = html.fromstring(page.content)
    return tree

# %%
url = "https://www.rei.com/c/backpacking-tents"
get(url)
# Out:
# <Element html at 0x24c1eca18b8>
